# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
columns = [
    "symboling", "normalized-losses", "make", "fuel-type", "aspiration",
    "num-of-doors", "body-style", "drive-wheels", "engine-location",
    "wheel-base", "length", "width", "height", "curb-weight", "engine-type",
    "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke",
    "compression-ratio", "horsepower", "peak-rpm", "city-mpg", "highway-mpg",
    "price"
]

df = pd.read_csv("automobile.csv", names=columns)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.info()
df.isnull.sum()

# %%
df['price'].replace('?', np.nan, inplace=True)
df['price'] = df['price'].astype('float')
df['price'].fillna(df['price'].mean(), inplace=True)
 
df['fuel-type'].replace('?', np.nan, inplace=True)
df['fuel-type'].fillna(df['fuel-type'].mode()[0], inplace=True)
import pandas as pd
columns = [
    "symboling", "normalized-losses", "make", "fuel-type", "aspiration",
    "num-of-doors", "body-style", "drive-wheels", "engine-location",
    "wheel-base", "length", "width", "height", "curb-weight", "engine-type",
    "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke",
    "compression-ratio", "horsepower", "peak-rpm", "city-mpg", "highway-mpg",
    "price"
]

df = pd.read_csv("automobile.csv", names=columns)
df.head()
# Out:
# /tmp/ipykernel_10521/1697836487.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].replace('?', np.nan, inplace=True)
# /tmp/ipykernel_10521/1697836487.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
cols_to_numeric = ['price', 'horsepower', 'engine-size']
for col in cols_to_numeric:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.describe()
df.describe(include='all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# ...

# %%
df_encoded = pd.get_dummies(df, columns=['fuel-type', 'body-style'])
df_encoded.head()
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3                 ?  alfa-romero        std          two
# 1          3                 ?  alfa-romero        std          two
# 2          1                 ?  alfa-romero        std          two
# 3          2               164         audi        std         four
# 4          2               164         audi        std         four
#
#   drive-wheels engine-location  wheel-base  length  width  ...  city-mpg  \
# 0          rwd           front        88.6   168.8   64.1  ...        21
# 1          rwd           front        88.6   168.8   64.1  ...        21
# 2          rwd           front        94.5   171.2   65.5  ...        19
# 3          fwd           front        99.8   176.6   66.2  ...        24
# 4          4wd           front        99.4   176.6   66.4  ...        18
#
#    highway-mpg    price fuel-type_diesel  fuel-type_gas  \
# 0           27  13495.0            False           True
# ...

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['price'], bins=30, kde=True)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
df_encoded = pd.get_dummies(df, columns=['fuel-type', 'body-style'])
df_encoded.head()
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3                 ?  alfa-romero        std          two
# 1          3                 ?  alfa-romero        std          two
# 2          1                 ?  alfa-romero        std          two
# 3          2               164         audi        std         four
# 4          2               164         audi        std         four
#
#   drive-wheels engine-location  wheel-base  length  width  ...  city-mpg  \
# 0          rwd           front        88.6   168.8   64.1  ...        21
# 1          rwd           front        88.6   168.8   64.1  ...        21
# 2          rwd           front        94.5   171.2   65.5  ...        19
# 3          fwd           front        99.8   176.6   66.2  ...        24
# 4          4wd           front        99.4   176.6   66.4  ...        18
#
#    highway-mpg    price fuel-type_diesel  fuel-type_gas  \
# 0           27  13495.0            False           True
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='body-style', y='price', data=df)
plt.title('Price Distribution by Body Style')

plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='engine-size', y='price', data=df)
plt.title('Engine Size vs Price')
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(8,6))
corr = df[['price', 'engine-size', 'horsepower']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
pivot = df.pivot_table(values='price', index='drive-wheels', columns='body-style', aggfunc='mean')
print(pivot)

plt.figure(figsize=(10,6))
sns.heatmap(pivot, annot=True, fmt=".0f", cmap='YlGnBu')
plt.title('Average Price by Drive Wheels and Body Style')
plt.show()
# Out:
# body-style    convertible       hardtop     hatchback         sedan  \
# drive-wheels
# 4wd                   NaN           NaN   7603.000000  12647.333333
# fwd               11595.0   8249.000000   8396.387755   9811.800000
# rwd               23949.6  24202.714286  14337.777778  21711.833333
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Step 10. Interpretation
# Task 8.1: Histogram of Prices
# ✔ What does the distribution show?
#     • The histogram shows how car prices are distributed in the dataset.
#     • Most cars are clustered at lower price ranges, indicating that affordable cars are more common.
#     • The right tail is longer, showing a positive skew, meaning there are few high-priced cars acting as outliers.
#
# Task 8.2: Boxplot of Price by Body Style
# ✔ Which body style has the highest average price?
#     • The boxplot displays price distribution across different body styles.
#     • Generally, convertibles or hardtops (if present) tend to have a higher median price compared to hatchbacks or sedans.
#     • You can confirm the exact highest body style by observing which boxplot median line is at the highest price level.
#
# Task 8.3: Scatter Plot of Engine Size vs. Price
# ✔ How does engine size relate to price?
#     • The scatter plot shows a positive linear relationship.
#     • As engine size increases, the price also tends to increase.
#     • This implies cars with larger engines are generally more expensive, likely due to better performance specifications.
#
# Task 8.4: Correlation Heatmap
# ✔ Which variables are highly correlated?
#     • The heatmap shows correlation coefficients between selected variables:
#         ◦ Price and engine size: Strong positive correlation (close to +0.85 or higher).
#         ◦ Price and horsepower: Also shows a strong positive correlation.
#     • This means both engine size and horsepower are good predictors of car price.
#
# Step 9: GroupBy Pivot Table Analysis
# ✔ Average price by drive wheels and body style
#     • The pivot table displays the average price for each combination of drive wheels and body style.
#     • The heatmap visualizes it clearly:
#         ◦ Rear-wheel drive convertibles or hardtops often have the highest average prices.
#         ◦ Four-wheel drive hatchbacks or sedans may have lower average prices.
#
# ✨Final Summary Interpretation
# ✅ Overall insights:
#     • Affordable cars are most common.
#     • Body style and drive type impact car price significantly.
#     • Engine size and horsepower are strong determinants of price.
